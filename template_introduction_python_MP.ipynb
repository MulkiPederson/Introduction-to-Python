# %% [markdown]
# ## Buatlah sebuah program yang:
#
#    1. Meminta input dari pengguna:
#
#        - Nama mahasiswa
#
#        - NIM mahasiswa
#
#        - Nilai ujian (dalam angka, 0–100)
#
#    2. Cek dan tampilkan tipe data dari setiap input.
#
#    3. Gunakan if-elif-else untuk menentukan kategori nilai, dengan kriteria sebagai berikut:
#
# ```
# Nilai | Kategori
# 85 - 100 | A (Sangat Baik)
# 75 - 84 | B (Baik)
# 60 - 74 | C (Cukup)
# 40 - 59 | D (Kurang)
# < 40 | E (Sangat Kurang)
# ```
#
# ```
# ==== Ekspektasi Output Jawaban : =====
# Masukkan nama mahasiswa: Sarah
# Masukkan NIM: 12345678
# Masukkan nilai ujian (0-100): 81
#
# Nama: Sarah (type: <class 'str'>)
# NIM: 12345678 (type: <class 'str'>)
# Nilai: 81 (type: <class 'int'>)
#
# Hasil Evaluasi:
# Mahasiswa: Sarah (NIM: 12345678)
# Nilai Ujian: 81
# Kategori Nilai: B (Baik)
# ```

# %% [markdown]
# Jawaban
# ## Code Manual

# %%
#Deklarasi Data/Variabel
Nama = "Sarah"
NIM = "12345678"
Nilai = 81

print(f"Masukkan Nama Anda: {Nama}")
print(f"Masukkan NIM Anda: {NIM}")
print(f"Masukkan Hasil Ujian (0-100): {Nilai}\n")

#Mengetahui type data berdasarkan variabel
print(f"Nama: {Nama} (type: {type(Nama)})")
print(f"NIM: {NIM} (type: {type(NIM)})")
print(f"Nilai: {Nilai} (type: {type(Nilai)})\n")

#Melakukan Pengkondisian Kategori Sesuai Nilai
if 85 <= Nilai <= 100:
    KategoriNilai = "A (Sangat Baik)"
elif 75 <= Nilai <= 84:
    KategoriNilai = "B (Baik)"
elif 60 <= Nilai <= 74:
   KategoriNilai = "C (Cukup)"
elif 40 <= Nilai <= 59:
    KategoriNilai = "D (Kurang)"
else:
   KategoriNilai = "E (Sangat Kurang)"

#Hasill
print("Hasil Evaluasi Sebagai Berikut:")
print(f"Nama Mahasiswa: {Nama} dengan NIM: {NIM}")
print(f"Nilai Ujian: {Nilai}")
print(f"Kategori Nilai: {KategoriNilai}")
# Out:
# Masukkan Nama Anda: Sarah
# Masukkan NIM Anda: 12345678
# Masukkan Hasil Ujian (0-100): 81
#
# Nama: Sarah (type: <class 'str'>)
# NIM: 12345678 (type: <class 'str'>)
# Nilai: 81 (type: <class 'int'>)
#
# Hasil Evaluasi Sebagai Berikut:
# Nama Mahasiswa: Sarah dengan NIM: 12345678
# Nilai Ujian: 81
# Kategori Nilai: B (Baik)

# %% [markdown]
# ## Code dengan `input`

# %%
# Input data dari pengguna
nama = input("Masukkan nama mahasiswa: ")
nim = input("Masukkan NIM: ")
nilai = int(input(f"Masukkan nilai ujian (0-100): "))

# Cetak data dengan tipe
print(f"\nNama: {nama} (type: {type(nama)})")
print(f"NIM: {nim} (type: {type(nim)})")
print(f"Nilai: {nilai} (type: {type(nilai)})")

# Menentukan kategori nilai
if 85 <= nilai <= 100:
    kategori = "A (Sangat Baik)"
elif 70 <= nilai < 85:
    kategori = "B (Baik)"
elif 55 <= nilai < 70:
    kategori = "C (Cukup)"
elif 40 <= nilai < 55:
    kategori = "D (Kurang)"
else:
    kategori = "E (Sangat Kurang)"

# Output hasil evaluasi
print("\nHasil Evaluasi:")
print(f"Mahasiswa: {nama} (NIM: {nim})")
print(f"Nilai Ujian: {nilai}")
print(f"Kategori Nilai: {kategori}")
# Out:
# Masukkan nama mahasiswa: Sarah
# Masukkan NIM: 12345678
# Masukkan nilai ujian (0-100): 86
#
# Nama: Sarah (type: <class 'str'>)
# NIM: 12345678 (type: <class 'str'>)
# Nilai: 86 (type: <class 'int'>)
#
# Hasil Evaluasi:
# Mahasiswa: Sarah (NIM: 12345678)
# Nilai Ujian: 86
# Kategori Nilai: A (Sangat Baik)

# %% [markdown]
# ### Observasi
#
# *   Menggunakan input() untuk membaca data dari pengguna.
# *   Mengonversi nilai ujian dari string ke int agar bisa dievaluasi.
# *   Menggunakan if-elif untuk menentukan kategori nilai sesuai rentang.
# *   Menampilkan semua informasi termasuk tipe data sesuai permintaan.
